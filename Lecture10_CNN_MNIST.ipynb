# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDED00R/machinelearning/blob/main/Lecture10_CNN_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 10):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Train Epoch: 9 | Batch Status: 3200/60000 (5%) | Loss: 0.032089
# Train Epoch: 9 | Batch Status: 3840/60000 (6%) | Loss: 0.034909
# Train Epoch: 9 | Batch Status: 4480/60000 (7%) | Loss: 0.009963
# Train Epoch: 9 | Batch Status: 5120/60000 (9%) | Loss: 0.114862
# Train Epoch: 9 | Batch Status: 5760/60000 (10%) | Loss: 0.009309
# Train Epoch: 9 | Batch Status: 6400/60000 (11%) | Loss: 0.074461
# Train Epoch: 9 | Batch Status: 7040/60000 (12%) | Loss: 0.131663
# Train Epoch: 9 | Batch Status: 7680/60000 (13%) | Loss: 0.030535
# Train Epoch: 9 | Batch Status: 8320/60000 (14%) | Loss: 0.039867
# Train Epoch: 9 | Batch Status: 8960/60000 (15%) | Loss: 0.056245
# Train Epoch: 9 | Batch Status: 9600/60000 (16%) | Loss: 0.127311
# Train Epoch: 9 | Batch Status: 10240/60000 (17%) | Loss: 0.086779
# Train Epoch: 9 | Batch Status: 10880/60000 (18%) | Loss: 0.035014
# Train Epoch: 9 | Batch Status: 11520/60000 (19%) | Loss: 0.055682
# Train Epoch: 9 | Batch Status: 12160/60000 (20%) | Loss: 0.073267
# Train Epoch: 9 | Batch Status: 12800/60000 (21%) | Loss: 0.068587
# Train Epoch: 9 | Batch Status: 13440/60000 (22%) | Loss: 0.083520
# Train Epoch: 9 | Batch Status: 14080/60000 (23%) | Loss: 0.052983
# Train Epoch: 9 | Batch Status: 14720/60000 (25%) | Loss: 0.009309
# Train Epoch: 9 | Batch Status: 15360/60000 (26%) | Loss: 0.173930
# Train Epoch: 9 | Batch Status: 16000/60000 (27%) | Loss: 0.051045
# Train Epoch: 9 | Batch Status: 16640/60000 (28%) | Loss: 0.049232
# Train Epoch: 9 | Batch Status: 17280/60000 (29%) | Loss: 0.020813
# Train Epoch: 9 | Batch Status: 17920/60000 (30%) | Loss: 0.013994
# Train Epoch: 9 | Batch Status: 18560/60000 (31%) | Loss: 0.120081
# Train Epoch: 9 | Batch Status: 19200/60000 (32%) | Loss: 0.011927
# Train Epoch: 9 | Batch Status: 19840/60000 (33%) | Loss: 0.022983
# Train Epoch: 9 | Batch Status: 20480/60000 (34%) | Loss: 0.033390
# Train Epoch: 9 | Batch Status: 21120/60000 (35%) | Loss: 0.024586
# Train Epoch: 9 | Batch Status: 21760/60000 (36%) | Loss: 0.106782
# Train Epoch: 9 | Batch Status: 22400/60000 (37%) | Loss: 0.056101
# Train Epoch: 9 | Batch Status: 23040/60000 (38%) | Loss: 0.096201
# Train Epoch: 9 | Batch Status: 23680/60000 (39%) | Loss: 0.069782
# Train Epoch: 9 | Batch Status: 24320/60000 (41%) | Loss: 0.025176
# Train Epoch: 9 | Batch Status: 24960/60000 (42%) | Loss: 0.049865
# Train Epoch: 9 | Batch Status: 25600/60000 (43%) | Loss: 0.045665
# Train Epoch: 9 | Batch Status: 26240/60000 (44%) | Loss: 0.074568
# Train Epoch: 9 | Batch Status: 26880/60000 (45%) | Loss: 0.020619
# Train Epoch: 9 | Batch Status: 27520/60000 (46%) | Loss: 0.162914
# Train Epoch: 9 | Batch Status: 28160/60000 (47%) | Loss: 0.143763
# Train Epoch: 9 | Batch Status: 28800/60000 (48%) | Loss: 0.010994
# Train Epoch: 9 | Batch Status: 29440/60000 (49%) | Loss: 0.107749
# Train Epoch: 9 | Batch Status: 30080/60000 (50%) | Loss: 0.013552
# Train Epoch: 9 | Batch Status: 30720/60000 (51%) | Loss: 0.082115
# Train Epoch: 9 | Batch Status: 31360/60000 (52%) | Loss: 0.062765
# Train Epoch: 9 | Batch Status: 32000/60000 (53%) | Loss: 0.043583
# Train Epoch: 9 | Batch Status: 32640/60000 (54%) | Loss: 0.119764
# Train Epoch: 9 | Batch Status: 33280/60000 (55%) | Loss: 0.034726
# Train Epoch: 9 | Batch Status: 33920/60000 (57%) | Loss: 0.044307
# Train Epoch: 9 | Batch Status: 34560/60000 (58%) | Loss: 0.067869
# Train Epoch: 9 | Batch Status: 35200/60000 (59%) | Loss: 0.050867
# Train Epoch: 9 | Batch Status: 35840/60000 (60%) | Loss: 0.040410
# Train Epoch: 9 | Batch Status: 36480/60000 (61%) | Loss: 0.062908
# Train Epoch: 9 | Batch Status: 37120/60000 (62%) | Loss: 0.019699
# Train Epoch: 9 | Batch Status: 37760/60000 (63%) | Loss: 0.019869
# Train Epoch: 9 | Batch Status: 38400/60000 (64%) | Loss: 0.035919
# Train Epoch: 9 | Batch Status: 39040/60000 (65%) | Loss: 0.029022
# Train Epoch: 9 | Batch Status: 39680/60000 (66%) | Loss: 0.070872
# Train Epoch: 9 | Batch Status: 40320/60000 (67%) | Loss: 0.053534
# Train Epoch: 9 | Batch Status: 40960/60000 (68%) | Loss: 0.175938
# Train Epoch: 9 | Batch Status: 41600/60000 (69%) | Loss: 0.044358
# Train Epoch: 9 | Batch Status: 42240/60000 (70%) | Loss: 0.125777
# Train Epoch: 9 | Batch Status: 42880/60000 (71%) | Loss: 0.027171
# Train Epoch: 9 | Batch Status: 43520/60000 (72%) | Loss: 0.265726
# Train Epoch: 9 | Batch Status: 44160/60000 (74%) | Loss: 0.055653
# Train Epoch: 9 | Batch Status: 44800/60000 (75%) | Loss: 0.049217
# Train Epoch: 9 | Batch Status: 45440/60000 (76%) | Loss: 0.075989
# Train Epoch: 9 | Batch Status: 46080/60000 (77%) | Loss: 0.003246
# Train Epoch: 9 | Batch Status: 46720/60000 (78%) | Loss: 0.032690
# Train Epoch: 9 | Batch Status: 47360/60000 (79%) | Loss: 0.042437
# Train Epoch: 9 | Batch Status: 48000/60000 (80%) | Loss: 0.080605
# Train Epoch: 9 | Batch Status: 48640/60000 (81%) | Loss: 0.087404
# Train Epoch: 9 | Batch Status: 49280/60000 (82%) | Loss: 0.017585
# Train Epoch: 9 | Batch Status: 49920/60000 (83%) | Loss: 0.010288
# Train Epoch: 9 | Batch Status: 50560/60000 (84%) | Loss: 0.021499
# Train Epoch: 9 | Batch Status: 51200/60000 (85%) | Loss: 0.111356
# Train Epoch: 9 | Batch Status: 51840/60000 (86%) | Loss: 0.018266
# Train Epoch: 9 | Batch Status: 52480/60000 (87%) | Loss: 0.100375
# Train Epoch: 9 | Batch Status: 53120/60000 (88%) | Loss: 0.048052
# Train Epoch: 9 | Batch Status: 53760/60000 (90%) | Loss: 0.084067
# Train Epoch: 9 | Batch Status: 54400/60000 (91%) | Loss: 0.041537
# Train Epoch: 9 | Batch Status: 55040/60000 (92%) | Loss: 0.103586
# Train Epoch: 9 | Batch Status: 55680/60000 (93%) | Loss: 0.049621
# Train Epoch: 9 | Batch Status: 56320/60000 (94%) | Loss: 0.094186
# Train Epoch: 9 | Batch Status: 56960/60000 (95%) | Loss: 0.033719
# Train Epoch: 9 | Batch Status: 57600/60000 (96%) | Loss: 0.045999
# Train Epoch: 9 | Batch Status: 58240/60000 (97%) | Loss: 0.019445
# Train Epoch: 9 | Batch Status: 58880/60000 (98%) | Loss: 0.010946
# Train Epoch: 9 | Batch Status: 59520/60000 (99%) | Loss: 0.045467
# Training time: 0m 10s
# ===========================
# Test set: Average loss: 0.0009, Accuracy: 9817/10000 (98%)
# Testing time: 0m 11s
# Total Time: 1m 42s
# Model was trained on cuda!

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

        nn.init.normal_(self.conv1.weight)
        nn.init.normal_(self.conv2.weight)
        nn.init.normal_(self.fc.weight)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 1738.640503
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 2.341700
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 2.307068
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 2.309863
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 2.325027
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 2.299693
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 2.306794
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 2.300881
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 2.317391
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 2.297327
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 2.302484
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 2.295209
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 2.303174
# Train Epoch: 1 | Batch Status: 8320/60000 (14%) | Loss: 2.302819
# Train Epoch: 1 | Batch Status: 8960/60000 (15%) | Loss: 2.306864
# Train Epoch: 1 | Batch Status: 9600/60000 (16%) | Loss: 2.296259
# Train Epoch: 1 | Batch Status: 10240/60000 (17%) | Loss: 2.295997
# Train Epoch: 1 | Batch Status: 10880/60000 (18%) | Loss: 2.290782
# Train Epoch: 1 | Batch Status: 11520/60000 (19%) | Loss: 2.305791
# Train Epoch: 1 | Batch Status: 12160/60000 (20%) | Loss: 2.302688
# Train Epoch: 1 | Batch Status: 12800/60000 (21%) | Loss: 2.289417
# Train Epoch: 1 | Batch Status: 13440/60000 (22%) | Loss: 2.299955
# Train Epoch: 1 | Batch Status: 14080/60000 (23%) | Loss: 2.436976
# Train Epoch: 1 | Batch Status: 14720/60000 (25%) | Loss: 2.306006
# Train Epoch: 1 | Batch Status: 15360/60000 (26%) | Loss: 2.305061
# Train Epoch: 1 | Batch Status: 16000/60000 (27%) | Loss: 2.293621
# Train Epoch: 1 | Batch Status: 16640/60000 (28%) | Loss: 2.300261
# Train Epoch: 1 | Batch Status: 17280/60000 (29%) | Loss: 2.311648
# Train Epoch: 1 | Batch Status: 17920/60000 (30%) | Loss: 2.290575
# Train Epoch: 1 | Batch Status: 18560/60000 (31%) | Loss: 2.306404
# Train Epoch: 1 | Batch Status: 19200/60000 (32%) | Loss: 2.298805
# Train Epoch: 1 | Batch Status: 19840/60000 (33%) | Loss: 2.297137
# Train Epoch: 1 | Batch Status: 20480/60000 (34%) | Loss: 2.306720
# Train Epoch: 1 | Batch Status: 21120/60000 (35%) | Loss: 2.309684
# Train Epoch: 1 | Batch Status: 21760/60000 (36%) | Loss: 2.294629
# Train Epoch: 1 | Batch Status: 22400/60000 (37%) | Loss: 2.305971
# Train Epoch: 1 | Batch Status: 23040/60000 (38%) | Loss: 2.296875
# Train Epoch: 1 | Batch Status: 23680/60000 (39%) | Loss: 2.294703
# Train Epoch: 1 | Batch Status: 24320/60000 (41%) | Loss: 2.296486
# Train Epoch: 1 | Batch Status: 24960/60000 (42%) | Loss: 2.303495
# Train Epoch: 1 | Batch Status: 25600/60000 (43%) | Loss: 2.448694
# Train Epoch: 1 | Batch Status: 26240/60000 (44%) | Loss: 2.305236
# Train Epoch: 1 | Batch Status: 26880/60000 (45%) | Loss: 2.293937
# Train Epoch: 1 | Batch Status: 27520/60000 (46%) | Loss: 2.297741
# Train Epoch: 1 | Batch Status: 28160/60000 (47%) | Loss: 2.301594
# Train Epoch: 1 | Batch Status: 28800/60000 (48%) | Loss: 2.288986
# Train Epoch: 1 | Batch Status: 29440/60000 (49%) | Loss: 2.312512
# Train Epoch: 1 | Batch Status: 30080/60000 (50%) | Loss: 2.308141
# Train Epoch: 1 | Batch Status: 30720/60000 (51%) | Loss: 2.299178
# Train Epoch: 1 | Batch Status: 31360/60000 (52%) | Loss: 2.294630
# Train Epoch: 1 | Batch Status: 32000/60000 (53%) | Loss: 2.307576
# Train Epoch: 1 | Batch Status: 32640/60000 (54%) | Loss: 2.306344
# Train Epoch: 1 | Batch Status: 33280/60000 (55%) | Loss: 2.361090
# Train Epoch: 1 | Batch Status: 33920/60000 (57%) | Loss: 2.307178
# Train Epoch: 1 | Batch Status: 34560/60000 (58%) | Loss: 2.299680
# Train Epoch: 1 | Batch Status: 35200/60000 (59%) | Loss: 2.293205
# Train Epoch: 1 | Batch Status: 35840/60000 (60%) | Loss: 2.301399
# Train Epoch: 1 | Batch Status: 36480/60000 (61%) | Loss: 2.302337
# Train Epoch: 1 | Batch Status: 37120/60000 (62%) | Loss: 2.299441
# Train Epoch: 1 | Batch Status: 37760/60000 (63%) | Loss: 2.303850
# Train Epoch: 1 | Batch Status: 38400/60000 (64%) | Loss: 2.292771
# Train Epoch: 1 | Batch Status: 39040/60000 (65%) | Loss: 2.302566
# Train Epoch: 1 | Batch Status: 39680/60000 (66%) | Loss: 2.297289
# Train Epoch: 1 | Batch Status: 40320/60000 (67%) | Loss: 2.303587
# Train Epoch: 1 | Batch Status: 40960/60000 (68%) | Loss: 2.299326
# Train Epoch: 1 | Batch Status: 41600/60000 (69%) | Loss: 2.299746
# Train Epoch: 1 | Batch Status: 42240/60000 (70%) | Loss: 2.296164
# Train Epoch: 1 | Batch Status: 42880/60000 (71%) | Loss: 2.293819
# Train Epoch: 1 | Batch Status: 43520/60000 (72%) | Loss: 2.307178
# Train Epoch: 1 | Batch Status: 44160/60000 (74%) | Loss: 2.297534
# Train Epoch: 1 | Batch Status: 44800/60000 (75%) | Loss: 2.301738
# Train Epoch: 1 | Batch Status: 45440/60000 (76%) | Loss: 2.309315
# Train Epoch: 1 | Batch Status: 46080/60000 (77%) | Loss: 2.296723
# Train Epoch: 1 | Batch Status: 46720/60000 (78%) | Loss: 2.299671
# Train Epoch: 1 | Batch Status: 47360/60000 (79%) | Loss: 2.297847
# Train Epoch: 1 | Batch Status: 48000/60000 (80%) | Loss: 2.306777
# Train Epoch: 1 | Batch Status: 48640/60000 (81%) | Loss: 2.300426
# Train Epoch: 1 | Batch Status: 49280/60000 (82%) | Loss: 2.296736
# Train Epoch: 1 | Batch Status: 49920/60000 (83%) | Loss: 2.293562
# Train Epoch: 1 | Batch Status: 50560/60000 (84%) | Loss: 2.303789
# Train Epoch: 1 | Batch Status: 51200/60000 (85%) | Loss: 2.303118
# Train Epoch: 1 | Batch Status: 51840/60000 (86%) | Loss: 2.295850
# Train Epoch: 1 | Batch Status: 52480/60000 (87%) | Loss: 2.297426
# Train Epoch: 1 | Batch Status: 53120/60000 (88%) | Loss: 2.301829
# Train Epoch: 1 | Batch Status: 53760/60000 (90%) | Loss: 2.300286
# Train Epoch: 1 | Batch Status: 54400/60000 (91%) | Loss: 2.296809
# Train Epoch: 1 | Batch Status: 55040/60000 (92%) | Loss: 2.381301
# Train Epoch: 1 | Batch Status: 55680/60000 (93%) | Loss: 2.302243
# Train Epoch: 1 | Batch Status: 56320/60000 (94%) | Loss: 2.307897
# Train Epoch: 1 | Batch Status: 56960/60000 (95%) | Loss: 2.291327
# Train Epoch: 1 | Batch Status: 57600/60000 (96%) | Loss: 2.294658
# Train Epoch: 1 | Batch Status: 58240/60000 (97%) | Loss: 2.286769
# Train Epoch: 1 | Batch Status: 58880/60000 (98%) | Loss: 2.300266
# Train Epoch: 1 | Batch Status: 59520/60000 (99%) | Loss: 2.303247
# Training time: 0m 10s
# ===========================
# Test set: Average loss: 0.0361, Accuracy: 1138/10000 (11%)
# Testing time: 0m 11s
# Total Time: 0m 11s
# Model was trained on cuda!

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

        nn.init.xavier_uniform_(self.conv1.weight)
        nn.init.xavier_uniform_(self.conv2.weight)
        nn.init.xavier_uniform_(self.fc.weight)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.315095
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 2.297149
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 2.268130
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 2.257919
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 2.219758
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 2.213517
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 2.187823
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 2.132440
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 2.097256
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 1.953948
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 1.929114
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 1.742265
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 1.466383
# Train Epoch: 1 | Batch Status: 8320/60000 (14%) | Loss: 1.193172
# Train Epoch: 1 | Batch Status: 8960/60000 (15%) | Loss: 1.069710
# Train Epoch: 1 | Batch Status: 9600/60000 (16%) | Loss: 0.856530
# Train Epoch: 1 | Batch Status: 10240/60000 (17%) | Loss: 0.678780
# Train Epoch: 1 | Batch Status: 10880/60000 (18%) | Loss: 0.609258
# Train Epoch: 1 | Batch Status: 11520/60000 (19%) | Loss: 0.667192
# Train Epoch: 1 | Batch Status: 12160/60000 (20%) | Loss: 0.581825
# Train Epoch: 1 | Batch Status: 12800/60000 (21%) | Loss: 0.533913
# Train Epoch: 1 | Batch Status: 13440/60000 (22%) | Loss: 0.477362
# Train Epoch: 1 | Batch Status: 14080/60000 (23%) | Loss: 0.431072
# Train Epoch: 1 | Batch Status: 14720/60000 (25%) | Loss: 0.487606
# Train Epoch: 1 | Batch Status: 15360/60000 (26%) | Loss: 0.496425
# Train Epoch: 1 | Batch Status: 16000/60000 (27%) | Loss: 0.294277
# Train Epoch: 1 | Batch Status: 16640/60000 (28%) | Loss: 0.448476
# Train Epoch: 1 | Batch Status: 17280/60000 (29%) | Loss: 0.367043
# Train Epoch: 1 | Batch Status: 17920/60000 (30%) | Loss: 0.689101
# Train Epoch: 1 | Batch Status: 18560/60000 (31%) | Loss: 0.369659
# Train Epoch: 1 | Batch Status: 19200/60000 (32%) | Loss: 0.307603
# Train Epoch: 1 | Batch Status: 19840/60000 (33%) | Loss: 0.385743
# Train Epoch: 1 | Batch Status: 20480/60000 (34%) | Loss: 0.397985
# Train Epoch: 1 | Batch Status: 21120/60000 (35%) | Loss: 0.473235
# Train Epoch: 1 | Batch Status: 21760/60000 (36%) | Loss: 0.372104
# Train Epoch: 1 | Batch Status: 22400/60000 (37%) | Loss: 0.368966
# Train Epoch: 1 | Batch Status: 23040/60000 (38%) | Loss: 0.419719
# Train Epoch: 1 | Batch Status: 23680/60000 (39%) | Loss: 0.412631
# Train Epoch: 1 | Batch Status: 24320/60000 (41%) | Loss: 0.351523
# Train Epoch: 1 | Batch Status: 24960/60000 (42%) | Loss: 0.509671
# Train Epoch: 1 | Batch Status: 25600/60000 (43%) | Loss: 0.296095
# Train Epoch: 1 | Batch Status: 26240/60000 (44%) | Loss: 0.536466
# Train Epoch: 1 | Batch Status: 26880/60000 (45%) | Loss: 0.254391
# Train Epoch: 1 | Batch Status: 27520/60000 (46%) | Loss: 0.376243
# Train Epoch: 1 | Batch Status: 28160/60000 (47%) | Loss: 0.284298
# Train Epoch: 1 | Batch Status: 28800/60000 (48%) | Loss: 0.210581
# Train Epoch: 1 | Batch Status: 29440/60000 (49%) | Loss: 0.301266
# Train Epoch: 1 | Batch Status: 30080/60000 (50%) | Loss: 0.297596
# Train Epoch: 1 | Batch Status: 30720/60000 (51%) | Loss: 0.417640
# Train Epoch: 1 | Batch Status: 31360/60000 (52%) | Loss: 0.482180
# Train Epoch: 1 | Batch Status: 32000/60000 (53%) | Loss: 0.263956
# Train Epoch: 1 | Batch Status: 32640/60000 (54%) | Loss: 0.191270
# Train Epoch: 1 | Batch Status: 33280/60000 (55%) | Loss: 0.398682
# Train Epoch: 1 | Batch Status: 33920/60000 (57%) | Loss: 0.277153
# Train Epoch: 1 | Batch Status: 34560/60000 (58%) | Loss: 0.263104
# Train Epoch: 1 | Batch Status: 35200/60000 (59%) | Loss: 0.404452
# Train Epoch: 1 | Batch Status: 35840/60000 (60%) | Loss: 0.125710
# Train Epoch: 1 | Batch Status: 36480/60000 (61%) | Loss: 0.144519
# Train Epoch: 1 | Batch Status: 37120/60000 (62%) | Loss: 0.551961
# Train Epoch: 1 | Batch Status: 37760/60000 (63%) | Loss: 0.120554
# Train Epoch: 1 | Batch Status: 38400/60000 (64%) | Loss: 0.252699
# Train Epoch: 1 | Batch Status: 39040/60000 (65%) | Loss: 0.213314
# Train Epoch: 1 | Batch Status: 39680/60000 (66%) | Loss: 0.196515
# Train Epoch: 1 | Batch Status: 40320/60000 (67%) | Loss: 0.169032
# Train Epoch: 1 | Batch Status: 40960/60000 (68%) | Loss: 0.414476
# Train Epoch: 1 | Batch Status: 41600/60000 (69%) | Loss: 0.205914
# Train Epoch: 1 | Batch Status: 42240/60000 (70%) | Loss: 0.287320
# Train Epoch: 1 | Batch Status: 42880/60000 (71%) | Loss: 0.166344
# Train Epoch: 1 | Batch Status: 43520/60000 (72%) | Loss: 0.383397
# Train Epoch: 1 | Batch Status: 44160/60000 (74%) | Loss: 0.172142
# Train Epoch: 1 | Batch Status: 44800/60000 (75%) | Loss: 0.177382
# Train Epoch: 1 | Batch Status: 45440/60000 (76%) | Loss: 0.214574
# Train Epoch: 1 | Batch Status: 46080/60000 (77%) | Loss: 0.308587
# Train Epoch: 1 | Batch Status: 46720/60000 (78%) | Loss: 0.332642
# Train Epoch: 1 | Batch Status: 47360/60000 (79%) | Loss: 0.354590
# Train Epoch: 1 | Batch Status: 48000/60000 (80%) | Loss: 0.152041
# Train Epoch: 1 | Batch Status: 48640/60000 (81%) | Loss: 0.162243
# Train Epoch: 1 | Batch Status: 49280/60000 (82%) | Loss: 0.412944
# Train Epoch: 1 | Batch Status: 49920/60000 (83%) | Loss: 0.176749
# Train Epoch: 1 | Batch Status: 50560/60000 (84%) | Loss: 0.216381
# Train Epoch: 1 | Batch Status: 51200/60000 (85%) | Loss: 0.216584
# Train Epoch: 1 | Batch Status: 51840/60000 (86%) | Loss: 0.143220
# Train Epoch: 1 | Batch Status: 52480/60000 (87%) | Loss: 0.302549
# Train Epoch: 1 | Batch Status: 53120/60000 (88%) | Loss: 0.139769
# Train Epoch: 1 | Batch Status: 53760/60000 (90%) | Loss: 0.225231
# Train Epoch: 1 | Batch Status: 54400/60000 (91%) | Loss: 0.107353
# Train Epoch: 1 | Batch Status: 55040/60000 (92%) | Loss: 0.391436
# Train Epoch: 1 | Batch Status: 55680/60000 (93%) | Loss: 0.164802
# Train Epoch: 1 | Batch Status: 56320/60000 (94%) | Loss: 0.097982
# Train Epoch: 1 | Batch Status: 56960/60000 (95%) | Loss: 0.114824
# Train Epoch: 1 | Batch Status: 57600/60000 (96%) | Loss: 0.157252
# Train Epoch: 1 | Batch Status: 58240/60000 (97%) | Loss: 0.307689
# Train Epoch: 1 | Batch Status: 58880/60000 (98%) | Loss: 0.253071
# Train Epoch: 1 | Batch Status: 59520/60000 (99%) | Loss: 0.130539
# Training time: 0m 10s
# ===========================
# Test set: Average loss: 0.0028, Accuracy: 9463/10000 (95%)
# Testing time: 0m 11s
# Total Time: 0m 11s
# Model was trained on cuda!

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)


    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
#criterion = nn.CrossEntropyLoss()
criterion=nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.301495
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 2.297648
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 2.300983
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 2.276787
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 2.274671
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 2.241196
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 2.229017
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 2.201825
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 2.195572
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 2.133016
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 2.099981
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 1.980547
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 1.815516
# Train Epoch: 1 | Batch Status: 8320/60000 (14%) | Loss: 1.700123
# Train Epoch: 1 | Batch Status: 8960/60000 (15%) | Loss: 1.423479
# Train Epoch: 1 | Batch Status: 9600/60000 (16%) | Loss: 1.103188
# Train Epoch: 1 | Batch Status: 10240/60000 (17%) | Loss: 0.939375
# Train Epoch: 1 | Batch Status: 10880/60000 (18%) | Loss: 0.652118
# Train Epoch: 1 | Batch Status: 11520/60000 (19%) | Loss: 0.773836
# Train Epoch: 1 | Batch Status: 12160/60000 (20%) | Loss: 0.585191
# Train Epoch: 1 | Batch Status: 12800/60000 (21%) | Loss: 0.573115
# Train Epoch: 1 | Batch Status: 13440/60000 (22%) | Loss: 0.530295
# Train Epoch: 1 | Batch Status: 14080/60000 (23%) | Loss: 0.655290
# Train Epoch: 1 | Batch Status: 14720/60000 (25%) | Loss: 0.589292
# Train Epoch: 1 | Batch Status: 15360/60000 (26%) | Loss: 0.437838
# Train Epoch: 1 | Batch Status: 16000/60000 (27%) | Loss: 0.480831
# Train Epoch: 1 | Batch Status: 16640/60000 (28%) | Loss: 0.288733
# Train Epoch: 1 | Batch Status: 17280/60000 (29%) | Loss: 0.571229
# Train Epoch: 1 | Batch Status: 17920/60000 (30%) | Loss: 0.547077
# Train Epoch: 1 | Batch Status: 18560/60000 (31%) | Loss: 0.580356
# Train Epoch: 1 | Batch Status: 19200/60000 (32%) | Loss: 0.402302
# Train Epoch: 1 | Batch Status: 19840/60000 (33%) | Loss: 0.443828
# Train Epoch: 1 | Batch Status: 20480/60000 (34%) | Loss: 0.404248
# Train Epoch: 1 | Batch Status: 21120/60000 (35%) | Loss: 0.414066
# Train Epoch: 1 | Batch Status: 21760/60000 (36%) | Loss: 0.365965
# Train Epoch: 1 | Batch Status: 22400/60000 (37%) | Loss: 0.530904
# Train Epoch: 1 | Batch Status: 23040/60000 (38%) | Loss: 0.327153
# Train Epoch: 1 | Batch Status: 23680/60000 (39%) | Loss: 0.277372
# Train Epoch: 1 | Batch Status: 24320/60000 (41%) | Loss: 0.271631
# Train Epoch: 1 | Batch Status: 24960/60000 (42%) | Loss: 0.240165
# Train Epoch: 1 | Batch Status: 25600/60000 (43%) | Loss: 0.465084
# Train Epoch: 1 | Batch Status: 26240/60000 (44%) | Loss: 0.218739
# Train Epoch: 1 | Batch Status: 26880/60000 (45%) | Loss: 0.212959
# Train Epoch: 1 | Batch Status: 27520/60000 (46%) | Loss: 0.346660
# Train Epoch: 1 | Batch Status: 28160/60000 (47%) | Loss: 0.379843
# Train Epoch: 1 | Batch Status: 28800/60000 (48%) | Loss: 0.364901
# Train Epoch: 1 | Batch Status: 29440/60000 (49%) | Loss: 0.370050
# Train Epoch: 1 | Batch Status: 30080/60000 (50%) | Loss: 0.348248
# Train Epoch: 1 | Batch Status: 30720/60000 (51%) | Loss: 0.289757
# Train Epoch: 1 | Batch Status: 31360/60000 (52%) | Loss: 0.366881
# Train Epoch: 1 | Batch Status: 32000/60000 (53%) | Loss: 0.453490
# Train Epoch: 1 | Batch Status: 32640/60000 (54%) | Loss: 0.288059
# Train Epoch: 1 | Batch Status: 33280/60000 (55%) | Loss: 0.329740
# Train Epoch: 1 | Batch Status: 33920/60000 (57%) | Loss: 0.331447
# Train Epoch: 1 | Batch Status: 34560/60000 (58%) | Loss: 0.335372
# Train Epoch: 1 | Batch Status: 35200/60000 (59%) | Loss: 0.321812
# Train Epoch: 1 | Batch Status: 35840/60000 (60%) | Loss: 0.214225
# Train Epoch: 1 | Batch Status: 36480/60000 (61%) | Loss: 0.352682
# Train Epoch: 1 | Batch Status: 37120/60000 (62%) | Loss: 0.195717
# Train Epoch: 1 | Batch Status: 37760/60000 (63%) | Loss: 0.245844
# Train Epoch: 1 | Batch Status: 38400/60000 (64%) | Loss: 0.126803
# Train Epoch: 1 | Batch Status: 39040/60000 (65%) | Loss: 0.263586
# Train Epoch: 1 | Batch Status: 39680/60000 (66%) | Loss: 0.312774
# Train Epoch: 1 | Batch Status: 40320/60000 (67%) | Loss: 0.218148
# Train Epoch: 1 | Batch Status: 40960/60000 (68%) | Loss: 0.120683
# Train Epoch: 1 | Batch Status: 41600/60000 (69%) | Loss: 0.286686
# Train Epoch: 1 | Batch Status: 42240/60000 (70%) | Loss: 0.208725
# Train Epoch: 1 | Batch Status: 42880/60000 (71%) | Loss: 0.206941
# Train Epoch: 1 | Batch Status: 43520/60000 (72%) | Loss: 0.316359
# Train Epoch: 1 | Batch Status: 44160/60000 (74%) | Loss: 0.316210
# Train Epoch: 1 | Batch Status: 44800/60000 (75%) | Loss: 0.173248
# Train Epoch: 1 | Batch Status: 45440/60000 (76%) | Loss: 0.142503
# Train Epoch: 1 | Batch Status: 46080/60000 (77%) | Loss: 0.087028
# Train Epoch: 1 | Batch Status: 46720/60000 (78%) | Loss: 0.209720
# Train Epoch: 1 | Batch Status: 47360/60000 (79%) | Loss: 0.362565
# Train Epoch: 1 | Batch Status: 48000/60000 (80%) | Loss: 0.324318
# Train Epoch: 1 | Batch Status: 48640/60000 (81%) | Loss: 0.259646
# Train Epoch: 1 | Batch Status: 49280/60000 (82%) | Loss: 0.300142
# Train Epoch: 1 | Batch Status: 49920/60000 (83%) | Loss: 0.163652
# Train Epoch: 1 | Batch Status: 50560/60000 (84%) | Loss: 0.212154
# Train Epoch: 1 | Batch Status: 51200/60000 (85%) | Loss: 0.092370
# Train Epoch: 1 | Batch Status: 51840/60000 (86%) | Loss: 0.387234
# Train Epoch: 1 | Batch Status: 52480/60000 (87%) | Loss: 0.165249
# Train Epoch: 1 | Batch Status: 53120/60000 (88%) | Loss: 0.199966
# Train Epoch: 1 | Batch Status: 53760/60000 (90%) | Loss: 0.175085
# Train Epoch: 1 | Batch Status: 54400/60000 (91%) | Loss: 0.134744
# Train Epoch: 1 | Batch Status: 55040/60000 (92%) | Loss: 0.219377
# Train Epoch: 1 | Batch Status: 55680/60000 (93%) | Loss: 0.195180
# Train Epoch: 1 | Batch Status: 56320/60000 (94%) | Loss: 0.144809
# Train Epoch: 1 | Batch Status: 56960/60000 (95%) | Loss: 0.077508
# Train Epoch: 1 | Batch Status: 57600/60000 (96%) | Loss: 0.227601
# Train Epoch: 1 | Batch Status: 58240/60000 (97%) | Loss: 0.107611
# Train Epoch: 1 | Batch Status: 58880/60000 (98%) | Loss: 0.140247
# Train Epoch: 1 | Batch Status: 59520/60000 (99%) | Loss: 0.224432
# Training time: 0m 10s
# ===========================
# Test set: Average loss: 0.0026, Accuracy: 9515/10000 (95%)
# Testing time: 0m 11s
# Total Time: 0m 11s
# Model was trained on cuda!

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)


    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
#criterion=nn.NLLLoss()
#optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)
optimizer=optim.Adam(model.parameters(), lr=0.01)

def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.293730
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 1.200971
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 0.577026
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 0.516907
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 0.210914
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 0.320492
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 0.192566
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 0.180519
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 0.153233
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 0.165273
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 0.208721
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 0.100735
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 0.109411
# Train Epoch: 1 | Batch Status: 8320/60000 (14%) | Loss: 0.058368
# Train Epoch: 1 | Batch Status: 8960/60000 (15%) | Loss: 0.211246
# Train Epoch: 1 | Batch Status: 9600/60000 (16%) | Loss: 0.090978
# Train Epoch: 1 | Batch Status: 10240/60000 (17%) | Loss: 0.167621
# Train Epoch: 1 | Batch Status: 10880/60000 (18%) | Loss: 0.115606
# Train Epoch: 1 | Batch Status: 11520/60000 (19%) | Loss: 0.024493
# Train Epoch: 1 | Batch Status: 12160/60000 (20%) | Loss: 0.187412
# Train Epoch: 1 | Batch Status: 12800/60000 (21%) | Loss: 0.065651
# Train Epoch: 1 | Batch Status: 13440/60000 (22%) | Loss: 0.236762
# Train Epoch: 1 | Batch Status: 14080/60000 (23%) | Loss: 0.139964
# Train Epoch: 1 | Batch Status: 14720/60000 (25%) | Loss: 0.124500
# Train Epoch: 1 | Batch Status: 15360/60000 (26%) | Loss: 0.068697
# Train Epoch: 1 | Batch Status: 16000/60000 (27%) | Loss: 0.083716
# Train Epoch: 1 | Batch Status: 16640/60000 (28%) | Loss: 0.426598
# Train Epoch: 1 | Batch Status: 17280/60000 (29%) | Loss: 0.181877
# Train Epoch: 1 | Batch Status: 17920/60000 (30%) | Loss: 0.100131
# Train Epoch: 1 | Batch Status: 18560/60000 (31%) | Loss: 0.186737
# Train Epoch: 1 | Batch Status: 19200/60000 (32%) | Loss: 0.142784
# Train Epoch: 1 | Batch Status: 19840/60000 (33%) | Loss: 0.052276
# Train Epoch: 1 | Batch Status: 20480/60000 (34%) | Loss: 0.047192
# Train Epoch: 1 | Batch Status: 21120/60000 (35%) | Loss: 0.014750
# Train Epoch: 1 | Batch Status: 21760/60000 (36%) | Loss: 0.047185
# Train Epoch: 1 | Batch Status: 22400/60000 (37%) | Loss: 0.070696
# Train Epoch: 1 | Batch Status: 23040/60000 (38%) | Loss: 0.041099
# Train Epoch: 1 | Batch Status: 23680/60000 (39%) | Loss: 0.079473
# Train Epoch: 1 | Batch Status: 24320/60000 (41%) | Loss: 0.118643
# Train Epoch: 1 | Batch Status: 24960/60000 (42%) | Loss: 0.117861
# Train Epoch: 1 | Batch Status: 25600/60000 (43%) | Loss: 0.018655
# Train Epoch: 1 | Batch Status: 26240/60000 (44%) | Loss: 0.062779
# Train Epoch: 1 | Batch Status: 26880/60000 (45%) | Loss: 0.017238
# Train Epoch: 1 | Batch Status: 27520/60000 (46%) | Loss: 0.048400
# Train Epoch: 1 | Batch Status: 28160/60000 (47%) | Loss: 0.071489
# Train Epoch: 1 | Batch Status: 28800/60000 (48%) | Loss: 0.081154
# Train Epoch: 1 | Batch Status: 29440/60000 (49%) | Loss: 0.134951
# Train Epoch: 1 | Batch Status: 30080/60000 (50%) | Loss: 0.129097
# Train Epoch: 1 | Batch Status: 30720/60000 (51%) | Loss: 0.038996
# Train Epoch: 1 | Batch Status: 31360/60000 (52%) | Loss: 0.019899
# Train Epoch: 1 | Batch Status: 32000/60000 (53%) | Loss: 0.023316
# Train Epoch: 1 | Batch Status: 32640/60000 (54%) | Loss: 0.110281
# Train Epoch: 1 | Batch Status: 33280/60000 (55%) | Loss: 0.111564
# Train Epoch: 1 | Batch Status: 33920/60000 (57%) | Loss: 0.028347
# Train Epoch: 1 | Batch Status: 34560/60000 (58%) | Loss: 0.158101
# Train Epoch: 1 | Batch Status: 35200/60000 (59%) | Loss: 0.217828
# Train Epoch: 1 | Batch Status: 35840/60000 (60%) | Loss: 0.135921
# Train Epoch: 1 | Batch Status: 36480/60000 (61%) | Loss: 0.018890
# Train Epoch: 1 | Batch Status: 37120/60000 (62%) | Loss: 0.109798
# Train Epoch: 1 | Batch Status: 37760/60000 (63%) | Loss: 0.085718
# Train Epoch: 1 | Batch Status: 38400/60000 (64%) | Loss: 0.082379
# Train Epoch: 1 | Batch Status: 39040/60000 (65%) | Loss: 0.134035
# Train Epoch: 1 | Batch Status: 39680/60000 (66%) | Loss: 0.136745
# Train Epoch: 1 | Batch Status: 40320/60000 (67%) | Loss: 0.083982
# Train Epoch: 1 | Batch Status: 40960/60000 (68%) | Loss: 0.033161
# Train Epoch: 1 | Batch Status: 41600/60000 (69%) | Loss: 0.021441
# Train Epoch: 1 | Batch Status: 42240/60000 (70%) | Loss: 0.131923
# Train Epoch: 1 | Batch Status: 42880/60000 (71%) | Loss: 0.043674
# Train Epoch: 1 | Batch Status: 43520/60000 (72%) | Loss: 0.034041
# Train Epoch: 1 | Batch Status: 44160/60000 (74%) | Loss: 0.090743
# Train Epoch: 1 | Batch Status: 44800/60000 (75%) | Loss: 0.076304
# Train Epoch: 1 | Batch Status: 45440/60000 (76%) | Loss: 0.045844
# Train Epoch: 1 | Batch Status: 46080/60000 (77%) | Loss: 0.010067
# Train Epoch: 1 | Batch Status: 46720/60000 (78%) | Loss: 0.035680
# Train Epoch: 1 | Batch Status: 47360/60000 (79%) | Loss: 0.065081
# Train Epoch: 1 | Batch Status: 48000/60000 (80%) | Loss: 0.063532
# Train Epoch: 1 | Batch Status: 48640/60000 (81%) | Loss: 0.109830
# Train Epoch: 1 | Batch Status: 49280/60000 (82%) | Loss: 0.011490
# Train Epoch: 1 | Batch Status: 49920/60000 (83%) | Loss: 0.217452
# Train Epoch: 1 | Batch Status: 50560/60000 (84%) | Loss: 0.048050
# Train Epoch: 1 | Batch Status: 51200/60000 (85%) | Loss: 0.187197
# Train Epoch: 1 | Batch Status: 51840/60000 (86%) | Loss: 0.316897
# Train Epoch: 1 | Batch Status: 52480/60000 (87%) | Loss: 0.124079
# Train Epoch: 1 | Batch Status: 53120/60000 (88%) | Loss: 0.016766
# Train Epoch: 1 | Batch Status: 53760/60000 (90%) | Loss: 0.027835
# Train Epoch: 1 | Batch Status: 54400/60000 (91%) | Loss: 0.015386
# Train Epoch: 1 | Batch Status: 55040/60000 (92%) | Loss: 0.045972
# Train Epoch: 1 | Batch Status: 55680/60000 (93%) | Loss: 0.119631
# Train Epoch: 1 | Batch Status: 56320/60000 (94%) | Loss: 0.047199
# Train Epoch: 1 | Batch Status: 56960/60000 (95%) | Loss: 0.003161
# Train Epoch: 1 | Batch Status: 57600/60000 (96%) | Loss: 0.202578
# Train Epoch: 1 | Batch Status: 58240/60000 (97%) | Loss: 0.030223
# Train Epoch: 1 | Batch Status: 58880/60000 (98%) | Loss: 0.050736
# Train Epoch: 1 | Batch Status: 59520/60000 (99%) | Loss: 0.035356
# Training time: 0m 10s
# ===========================
# Test set: Average loss: 0.0008, Accuracy: 9816/10000 (98%)
# Testing time: 0m 12s
# Total Time: 0m 12s
# Model was trained on cuda!
