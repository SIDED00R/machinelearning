# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDED00R/machinelearning/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cpu
# ============================================
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.298807
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 2.294179
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 2.293068
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 2.276668
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 2.276146
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 2.282078
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 2.257637
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 2.223081
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 2.199637
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 2.171273
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 2.150058
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 2.043317
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 1.945248
# Train Epoch: 1 | Batch Status: 8320/60000 (14%) | Loss: 1.806534
# Train Epoch: 1 | Batch Status: 8960/60000 (15%) | Loss: 1.664692
# Train Epoch: 1 | Batch Status: 9600/60000 (16%) | Loss: 1.378948
# Train Epoch: 1 | Batch Status: 10240/60000 (17%) | Loss: 1.204320
# Train Epoch: 1 | Batch Status: 10880/60000 (18%) | Loss: 1.132783
# Train Epoch: 1 | Batch Status: 11520/60000 (19%) | Loss: 0.782319
# Train Epoch: 1 | Batch Status: 12160/60000 (20%) | Loss: 0.641148
# Train Epoch: 1 | Batch Status: 12800/60000 (21%) | Loss: 0.688323
# Train Epoch: 1 | Batch Status: 13440/60000 (22%) | Loss: 0.701636
# Train Epoch: 1 | Batch Status: 14080/60000 (23%) | Loss: 0.772860
# Train Epoch: 1 | Batch Status: 14720/60000 (25%) | Loss: 0.687828
# Train Epoch: 1 | Batch Status: 15360/60000 (26%) | Loss: 0.633460
# Train Epoch: 1 | Batch Status: 16000/60000 (27%) | Loss: 0.462292
# Train Epoch: 1 | Batch Status: 16640/60000 (28%) | Loss: 0.482598
# Train Epoch: 1 | Batch Status: 17280/60000 (29%) | Loss: 0.371126
# Train Epoch: 1 | Batch Status: 43520/60000 (72%) | Loss: 0.342776
# Train Epoch: 1 | Batch Status: 44160/60000 (74%) | Loss: 0.343514
# Train Epoch: 1 | Batch Status: 44800/60000 (75%) | Loss: 0.183201
# Train Epoch: 1 | Batch Status: 45440/60000 (76%) | Loss: 0.202655
# Train Epoch: 1 | Batch Status: 46080/60000 (77%) | Loss: 0.180713
# Train Epoch: 1 | Batch Status: 46720/60000 (78%) | Loss: 0.275189
# Train Epoch: 1 | Batch Status: 47360/60000 (79%) | Loss: 0.144969
# Train Epoch: 1 | Batch Status: 48000/60000 (80%) | Loss: 0.123899
# Train Epoch: 1 | Batch Status: 48640/60000 (81%) | Loss: 0.247315
# Train Epoch: 1 | Batch Status: 49280/60000 (82%) | Loss: 0.278197
# Train Epoch: 1 | Batch Status: 49920/60000 (83%) | Loss: 0.275544
# Train Epoch: 1 | Batch Status: 50560/60000 (84%) | Loss: 0.153115
# Train Epoch: 1 | Batch Status: 51200/60000 (85%) | Loss: 0.225850
# Train Epoch: 1 | Batch Status: 51840/60000 (86%) | Loss: 0.208295
# Train Epoch: 1 | Batch Status: 52480/60000 (87%) | Loss: 0.189080
# Train Epoch: 1 | Batch Status: 53120/60000 (88%) | Loss: 0.346761
# Train Epoch: 1 | Batch Status: 53760/60000 (90%) | Loss: 0.319082
# Train Epoch: 1 | Batch Status: 54400/60000 (91%) | Loss: 0.167233
# Train Epoch: 1 | Batch Status: 55040/60000 (92%) | Loss: 0.173479
# Train Epoch: 1 | Batch Status: 55680/60000 (93%) | Loss: 0.141767
# Train Epoch: 1 | Batch Status: 56320/60000 (94%) | Loss: 0.186706
# Train Epoch: 1 | Batch Status: 56960/60000 (95%) | Loss: 0.141032
# Train Epoch: 1 | Batch Status: 57600/60000 (96%) | Loss: 0.293470
# Train Epoch: 1 | Batch Status: 58240/60000 (97%) | Loss: 0.181134
# Train Epoch: 1 | Batch Status: 58880/60000 (98%) | Loss: 0.194969
# Train Epoch: 1 | Batch Status: 59520/60000 (99%) | Loss: 0.126946
# Training time: 0m 18s
# ===========================
# Test set: Average loss: 0.0031, Accuracy: 9413/10000 (94%)
# Testing time: 0m 20s
# Total Time: 0m 20s
# Model was trained on cpu!

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)

        self.bn1=nn.BatchNorm2d(10)
        self.bn2=nn.BatchNorm2d(20)

        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        in_size = x.size(0)
        #x = F.relu(self.mp(self.conv1(x)))
        #x = F.relu(self.mp(self.conv2(x)))
        x = F.relu(self.mp(self.bn1(self.conv1(x))))
        x = F.relu(self.mp(self.bn2(self.conv2(x))))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:55: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.490858
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 0.510863
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 0.265686
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 0.222456
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 0.295735
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 0.250491
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 0.195758
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 0.143266
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 0.118973
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 0.157241
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 0.100789
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 0.119383
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 0.035213
# Train Epoch: 1 | Batch Status: 8320/60000 (14%) | Loss: 0.207772
# Train Epoch: 1 | Batch Status: 8960/60000 (15%) | Loss: 0.173064
# Train Epoch: 1 | Batch Status: 9600/60000 (16%) | Loss: 0.031859
# Train Epoch: 1 | Batch Status: 10240/60000 (17%) | Loss: 0.095779
# Train Epoch: 1 | Batch Status: 10880/60000 (18%) | Loss: 0.145171
# Train Epoch: 1 | Batch Status: 11520/60000 (19%) | Loss: 0.072908
# Train Epoch: 1 | Batch Status: 12160/60000 (20%) | Loss: 0.274065
# Train Epoch: 1 | Batch Status: 12800/60000 (21%) | Loss: 0.049956
# Train Epoch: 1 | Batch Status: 13440/60000 (22%) | Loss: 0.061993
# Train Epoch: 1 | Batch Status: 14080/60000 (23%) | Loss: 0.186288
# Train Epoch: 1 | Batch Status: 14720/60000 (25%) | Loss: 0.082253
# Train Epoch: 1 | Batch Status: 15360/60000 (26%) | Loss: 0.195618
# Train Epoch: 1 | Batch Status: 16000/60000 (27%) | Loss: 0.019936
# Train Epoch: 1 | Batch Status: 16640/60000 (28%) | Loss: 0.077377
# Train Epoch: 1 | Batch Status: 17280/60000 (29%) | Loss: 0.093347
# Train Epoch: 1 | Batch Status: 17920/60000 (30%) | Loss: 0.050779
# Train Epoch: 1 | Batch Status: 18560/60000 (31%) | Loss: 0.096584
# Train Epoch: 1 | Batch Status: 19200/60000 (32%) | Loss: 0.083840
# Train Epoch: 1 | Batch Status: 19840/60000 (33%) | Loss: 0.142842
# Train Epoch: 1 | Batch Status: 20480/60000 (34%) | Loss: 0.141192
# Train Epoch: 1 | Batch Status: 21120/60000 (35%) | Loss: 0.079558
# Train Epoch: 1 | Batch Status: 21760/60000 (36%) | Loss: 0.229815
# Train Epoch: 1 | Batch Status: 22400/60000 (37%) | Loss: 0.106030
# Train Epoch: 1 | Batch Status: 48640/60000 (81%) | Loss: 0.048535
# Train Epoch: 1 | Batch Status: 49280/60000 (82%) | Loss: 0.147124
# Train Epoch: 1 | Batch Status: 49920/60000 (83%) | Loss: 0.032559
# Train Epoch: 1 | Batch Status: 50560/60000 (84%) | Loss: 0.116898
# Train Epoch: 1 | Batch Status: 51200/60000 (85%) | Loss: 0.087220
# Train Epoch: 1 | Batch Status: 51840/60000 (86%) | Loss: 0.066255
# Train Epoch: 1 | Batch Status: 52480/60000 (87%) | Loss: 0.036874
# Train Epoch: 1 | Batch Status: 53120/60000 (88%) | Loss: 0.049284
# Train Epoch: 1 | Batch Status: 53760/60000 (90%) | Loss: 0.014773
# Train Epoch: 1 | Batch Status: 54400/60000 (91%) | Loss: 0.027187
# Train Epoch: 1 | Batch Status: 55040/60000 (92%) | Loss: 0.112307
# Train Epoch: 1 | Batch Status: 55680/60000 (93%) | Loss: 0.006514
# Train Epoch: 1 | Batch Status: 56320/60000 (94%) | Loss: 0.045681
# Train Epoch: 1 | Batch Status: 56960/60000 (95%) | Loss: 0.179129
# Train Epoch: 1 | Batch Status: 57600/60000 (96%) | Loss: 0.031996
# Train Epoch: 1 | Batch Status: 58240/60000 (97%) | Loss: 0.024854
# Train Epoch: 1 | Batch Status: 58880/60000 (98%) | Loss: 0.009987
# Train Epoch: 1 | Batch Status: 59520/60000 (99%) | Loss: 0.054578
# Training time: 0m 12s
# ===========================
# Test set: Average loss: 0.0007, Accuracy: 9867/10000 (99%)
# Testing time: 0m 14s
# Total Time: 0m 14s
# Model was trained on cuda!

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)

        self.bn1=nn.BatchNorm2d(10)
        self.bn2=nn.BatchNorm2d(20)

        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        #x = F.relu(self.mp(self.bn1(self.conv1(x))))
        #x = F.relu(self.mp(self.bn2(self.conv2(x))))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5, weight_decay=0.001)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.293472
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 2.275136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:55: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch:
# Train Epoch: 1 | Batch Status: 54400/60000 (91%) | Loss: 0.197749
# Train Epoch: 1 | Batch Status: 55040/60000 (92%) | Loss: 0.146253
# Train Epoch: 1 | Batch Status: 55680/60000 (93%) | Loss: 0.272623
# Train Epoch: 1 | Batch Status: 56320/60000 (94%) | Loss: 0.175498
# Train Epoch: 1 | Batch Status: 56960/60000 (95%) | Loss: 0.149351
# Train Epoch: 1 | Batch Status: 57600/60000 (96%) | Loss: 0.265998
# Train Epoch: 1 | Batch Status: 58240/60000 (97%) | Loss: 0.358681
# Train Epoch: 1 | Batch Status: 58880/60000 (98%) | Loss: 0.265854
# Train Epoch: 1 | Batch Status: 59520/60000 (99%) | Loss: 0.127018
# Training time: 0m 11s
# ===========================
# Test set: Average loss: 0.0027, Accuracy: 9500/10000 (95%)
# Testing time: 0m 13s
# Total Time: 0m 13s
# Model was trained on cuda!

# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)

        self.bn1=nn.BatchNorm2d(10)
        self.bn2=nn.BatchNorm2d(20)

        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        #x = F.relu(self.mp(self.bn1(self.conv1(x))))
        #x = F.relu(self.mp(self.bn2(self.conv2(x))))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

test_acc=[]
def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    test_acc.append(correct/len(test_loader.dataset))
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

        if(epoch>5 and test_acc[epoch-1]<test_acc[eopch-2]):
          print(f'early stop{epoch}:{test_acc[epoch-1]},{test_acc[epoch-2]}')


    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:55: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.304859
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 2.301891
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 2.281244
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 2.279744
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 2.275153
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 2.232323
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 2.208764
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 2.187030
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 2.179494
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 2.046898
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 2.009617
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 1.910138
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 1.661728
# %%
# https://github.com/pytorch/examples/blob/master/mnist/main.py
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time

transform_=transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize(mean=(0.1307),std=(0.3081)),
                               transforms.RandomAffine(degrees=45,translate=(0.1,0.1),scale=(0.8,1.2))])
# Training settings
batch_size = 64
device = 'cuda' if cuda.is_available() else 'cpu'
print(f'Training MNIST Model on {device}\n{"=" * 44}')

# MNIST Dataset
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transform_,
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)

        self.bn1=nn.BatchNorm2d(10)
        self.bn2=nn.BatchNorm2d(20)

        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        #x = F.relu(self.mp(self.bn1(self.conv1(x))))
        #x = F.relu(self.mp(self.bn2(self.conv2(x))))
        x = x.view(in_size, -1)  # flatten the tensor
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)


def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} | Batch Status: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

test_acc=[]
def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    test_acc.append(correct/len(test_loader.dataset))
    print(f'===========================\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({100. * correct / len(test_loader.dataset):.0f}%)')


if __name__ == '__main__':
    since = time.time()
    for epoch in range(1, 2):
        epoch_start = time.time()
        train(epoch)
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Training time: {m:.0f}m {s:.0f}s')
        test()
        m, s = divmod(time.time() - epoch_start, 60)
        print(f'Testing time: {m:.0f}m {s:.0f}s')

        if(epoch>5 and test_acc[epoch-1]<test_acc[eopch-2]):
          print(f'early stop{epoch}:{test_acc[epoch-1]},{test_acc[epoch-2]}')


    m, s = divmod(time.time() - since, 60)
    print(f'Total Time: {m:.0f}m {s:.0f}s\nModel was trained on {device}!')
# Out:
# Training MNIST Model on cuda
# ============================================
# Train Epoch: 1 | Batch Status: 0/60000 (0%) | Loss: 2.288240
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 | Batch Status: 640/60000 (1%) | Loss: 2.264067
# Train Epoch: 1 | Batch Status: 1280/60000 (2%) | Loss: 2.238411
# Train Epoch: 1 | Batch Status: 1920/60000 (3%) | Loss: 2.193096
# Train Epoch: 1 | Batch Status: 2560/60000 (4%) | Loss: 2.152636
# Train Epoch: 1 | Batch Status: 3200/60000 (5%) | Loss: 2.086920
# Train Epoch: 1 | Batch Status: 3840/60000 (6%) | Loss: 1.889740
# Train Epoch: 1 | Batch Status: 4480/60000 (7%) | Loss: 1.772962
# Train Epoch: 1 | Batch Status: 5120/60000 (9%) | Loss: 1.859319
# Train Epoch: 1 | Batch Status: 5760/60000 (10%) | Loss: 1.612224
# Train Epoch: 1 | Batch Status: 6400/60000 (11%) | Loss: 1.817989
# Train Epoch: 1 | Batch Status: 7040/60000 (12%) | Loss: 1.634310
# Train Epoch: 1 | Batch Status: 7680/60000 (13%) | Loss: 1.365639
# Train Epoch: 1 | Batch Status: 8320/60000 (14%) | Loss: 1.700594
# Train Epoch: 1 | Batch Status: 8960/60000 (15%) | Loss: 1.660236
# Train Epoch: 1 | Batch Status: 9600/60000 (16%) | Loss: 1.772351
# Train Epoch: 1 | Batch Status: 10240/60000 (17%) | Loss: 1.539683
